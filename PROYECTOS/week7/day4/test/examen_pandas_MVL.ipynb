# %% [markdown]
# # Examen Pandas - Unidad 1
#
# ## Mónica Villasuso López

# %% [markdown]
# ### Data Science The Bridge - 2020

# %% [markdown]
# Primero de todo, importa la que seguro es ya tu librería favorita y que vas a necesitar, seguro, para realizar este examen.

# %%
# no borres esto y ejecútalo junto con tu librería favorita
import warnings
warnings.simplefilter(action='ignore')

# aquí tu librería favorita
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %% [markdown]
# Para trabajar con **pandas** lo primero que necesitarás, son datos, en la vida real deberías entrar en este enlace de **kaggle** y descargar el dataset: https://www.kaggle.com/neuromusic/avocado-prices. Con el fin de poder leer el `.csv` sin problema, habría que copiarlo en la misma carpeta donde se encuentra este archivo `.ipynb`.
#
# Pero como esto es un examen, ya lo tienes en esta carpeta, por lo que solo tienes que leerlo. Asígnalo a la variable `avocado` y muestra las primeras 5 filas.
#
# **AVISO**: Al llamar a la función que lee el `.csv` no uses ningún argumento, solo el nombre del archivo `"avocado_kaggle.csv"`.

# %%
# your code here
avocado = pd.read_csv("avocado_kaggle.csv")
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# Lo primero que debe hacer un Data Scientist es conocer los datos con los que está trabajando, por esto, explora el dataset:
# - sacando los nombres de las distintas columnas,
# - qué tipo de datos contienen estas columnas,
# - cuántas filas y columnas tiene el dataframe,
# - además de un marco de datos de estadísticas descriptivas de dicho dataframe.
#
# Utiliza la función/funciones que te parezcan mejor para hacer dicha exploración.

# %%
# your code here
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
avocado.describe(include="all")
# Out:
#           Unnamed: 0        Date  AveragePrice  Total Volume          4046  \
# count   18249.000000       18249  18249.000000  1.824900e+04  1.824900e+04
# unique           NaN         169           NaN           NaN           NaN
# top              NaN  2016-08-07           NaN           NaN           NaN
# freq             NaN         108           NaN           NaN           NaN
# mean       24.232232         NaN      1.405978  8.506440e+05  2.930084e+05
# std        15.481045         NaN      0.402677  3.453545e+06  1.264989e+06
# min         0.000000         NaN      0.440000  8.456000e+01  0.000000e+00
# 25%        10.000000         NaN      1.100000  1.083858e+04  8.540700e+02
# 50%        24.000000         NaN      1.370000  1.073768e+05  8.645300e+03
# 75%        38.000000         NaN      1.660000  4.329623e+05  1.110202e+05
# max        52.000000         NaN      3.250000  6.250565e+07  2.274362e+07
#
#                 4225          4770    Total Bags    Small Bags    Large Bags  \
# count   1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.951546e+05  2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04
# std     1.204120e+06  1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     3.008780e+03  0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02
# 50%     2.906102e+04  1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03
# 75%     1.502069e+05  6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04
# max     2.047057e+07  2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06
#
#           XLarge Bags          type          year         region
# count    18249.000000         18249  18249.000000          18249
# unique            NaN             2           NaN             54
# top               NaN  conventional           NaN  SouthCarolina
# freq              NaN          9126           NaN            338
# mean      3106.426507           NaN   2016.147899            NaN
# std      17692.894652           NaN      0.939938            NaN
# min          0.000000           NaN   2015.000000            NaN
# 25%          0.000000           NaN   2015.000000            NaN
# 50%          0.000000           NaN   2016.000000            NaN
# 75%        132.500000           NaN   2017.000000            NaN
# max     551693.650000           NaN   2018.000000            NaN

# %% [markdown]
# Muestra el index número **2904** de la columna `Date`.

# %%
# your code here
avocado.iloc[2904,1]
# Out:
# '2016-02-21'

# %% [markdown]
# ¿De qué tipo es este valor?

# %%
# your answer here
type(avocado.iloc[2904,1])
# Out:
# str

# %% [markdown]
# Esta columna contiene fechas, por lo que para poder trabajarla como tal, pásala a tipo `datetime64[ns]`.
#
# Existe una forma de importar el archivo `.csv` estableciendo la columna `Date` como el index, si has hecho esto al importar el archivo, a pesar del AVISO, vuelve a importarlo sin incluir argumentos.

# %%
# your code here
avocado["Date"] = pd.to_datetime(avocado["Date"], format = "%Y-%m-%d")

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# Establece esta columna como el index de `avocado`.

# %%
# your code here
avocado.set_index("Date", inplace= True)

# %% [markdown]
# Muestra los 7 últimos valores del dataframe y observa que efectivamente se ha actualizado el index.

# %%
# your code here
avocado.tail(7)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046     4225    4770  \
# Date
# 2018-02-18           5          1.56      17597.12  1892.05  1928.36    0.00
# 2018-02-11           6          1.57      15986.17  1924.28  1368.32    0.00
# 2018-02-04           7          1.63      17074.83  2046.96  1529.20    0.00
# 2018-01-28           8          1.71      13888.04  1191.70  3431.50    0.00
# 2018-01-21           9          1.87      13766.76  1191.92  2452.79  727.94
# 2018-01-14          10          1.93      16205.22  1527.63  2981.04  727.01
# 2018-01-07          11          1.62      17489.58  2894.77  2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-02-18    13776.71    13553.53      223.18          0.0  organic  2018
# 2018-02-11    12693.57    12437.35      256.22          0.0  organic  2018
# 2018-02-04    13498.67    13066.82      431.85          0.0  organic  2018
# 2018-01-28     9264.84     8940.04      324.80          0.0  organic  2018
# 2018-01-21     9394.11     9351.80       42.31          0.0  organic  2018
# 2018-01-14    10969.54    10919.54       50.00          0.0  organic  2018
# 2018-01-07    12014.15    11988.14       26.01          0.0  organic  2018
#
#                       region
# Date
# 2018-02-18  WestTexNewMexico
# 2018-02-11  WestTexNewMexico
# 2018-02-04  WestTexNewMexico
# 2018-01-28  WestTexNewMexico
# 2018-01-21  WestTexNewMexico
# 2018-01-14  WestTexNewMexico
# 2018-01-07  WestTexNewMexico

# %% [markdown]
# Además si al leer el archivo `.csv` no eliminaste esta columna, el dataframe seguirá teniendo una columna llamada `Unnamed: 0` que contendría el valor de los index. Si es así, elimínala.

# %%
# your code here
avocado.drop ("Unnamed: 0", axis = 1, inplace=True)

# %% [markdown]
# ¿Qué columnas continúan siendo de tipo **object**? Usa al menos una función de **pandas** para ello.

# %%
# your code here
avocado.select_dtypes(include=object).columns
# Out:
# Index(['type', 'region'], dtype='object')

# %% [markdown]
# ¿Cuántos valores únicos encontramos en estas columnas que continúan siendo de tipo **object**?

# %%
# your code here
avocado.type.nunique()      # Cantidad de valores únicos de la columna type
# Out:
# 2

# %%
avocado.region.nunique()        # Cantidad de valores únicos de la columna region
# Out:
# 54

# %% [markdown]
# ¿Qué número de ocurrencias tiene cada uno de estos valores únicos en la columna en que se encuentra?

# %%
# your code here
avocado.type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
# your code here
avocado.region.value_counts()
# Out:
# SouthCarolina          338
# California             338
# DallasFtWorth          338
# TotalUS                338
# Indianapolis           338
# Nashville              338
# NewYork                338
# Albany                 338
# HarrisburgScranton     338
# Houston                338
# Jacksonville           338
# Chicago                338
# Pittsburgh             338
# Sacramento             338
# Boston                 338
# LosAngeles             338
# SanDiego               338
# Denver                 338
# MiamiFtLauderdale      338
# CincinnatiDayton       338
# NorthernNewEngland     338
# Tampa                  338
# Syracuse               338
# Atlanta                338
# HartfordSpringfield    338
# Northeast              338
# Charlotte              338
# SanFrancisco           338
# Southeast              338
# Portland               338
# GreatLakes             338
# Philadelphia           338
# GrandRapids            338
# SouthCentral           338
# Boise                  338
# RaleighGreensboro      338
# Orlando                338
# Roanoke                338
# West                   338
# Midsouth               338
# PhoenixTucson          338
# Spokane                338
# NewOrleansMobile       338
# Plains                 338
# Columbus               338
# BaltimoreWashington    338
# RichmondNorfolk        338
# LasVegas               338
# BuffaloRochester       338
# StLouis                338
# Detroit                338
# Louisville             338
# Seattle                338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %% [markdown]
# Ahora que hemos explorado el dataframe, podemos empezar a trabajar con ello. En este caso, ordena el `index` de manera que la fecha **2015-01-04** quede arriba.

# %%
avocado.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=18249, freq=None)

# %%
# your code here
avocado.sort_index(ascending = True, inplace = True)
avocado.head()
# Out:
#             AveragePrice  Total Volume     4046      4225     4770  \
# Date
# 2015-01-04          1.75      27365.89  9307.34   3844.81   615.28
# 2015-01-04          1.49      17723.17  1189.35  15628.27     0.00
# 2015-01-04          1.68       2896.72   161.68    206.96     0.00
# 2015-01-04          1.52      54956.80  3013.04  35456.88  1561.70
# 2015-01-04          1.64       1505.12     1.27   1129.50     0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04    13598.46    13061.10      537.36          0.0       organic
# 2015-01-04      905.55      905.55        0.00          0.0       organic
# 2015-01-04     2528.08     2528.08        0.00          0.0       organic
# 2015-01-04    14925.18    11264.80     3660.38          0.0  conventional
# 2015-01-04      374.35      186.67      187.68          0.0       organic
#
#             year              region
# Date
# 2015-01-04  2015           Southeast
# 2015-01-04  2015             Chicago
# 2015-01-04  2015  HarrisburgScranton
# 2015-01-04  2015          Pittsburgh
# 2015-01-04  2015               Boise

# %% [markdown]
# Agrupa el dataframe `avocado` por tipo y quédate con el mínimo del resto de las columnas.

# %%
# your code here
minxtype = avocado.groupby("type").min()
minxtype
# Out:
#               AveragePrice  Total Volume   4046    4225  4770  Total Bags  \
# type
# conventional          0.46      33699.68  72.06  1518.0   0.0     3047.17
# organic               0.44         84.56   0.00     0.0   0.0        0.00
#
#               Small Bags  Large Bags  XLarge Bags  year  region
# type
# conventional     1119.18         0.0          0.0  2015  Albany
# organic             0.00         0.0          0.0  2015  Albany

# %% [markdown]
# Además, queremos conocer el máximo de bolsas pequeñas, bolsas grandes y bolsas extragrandes de aguacates que se vendieron por año, por cada región. Crea un dataframe que se llame `group_bags` que muestre dicha información.

# %%
# your code here
group_bags = avocado.groupby(avocado.index.to_period('A'))["region","Small Bags", "Large Bags", "XLarge Bags"].max()

# %%
group_bags
# Out:
#                 region   Small Bags  Large Bags  XLarge Bags
# Date
# 2015  WestTexNewMexico   5893641.72  1371440.28    199305.12
# 2016  WestTexNewMexico   9967538.34  3373077.87    551693.65
# 2017  WestTexNewMexico  12567155.58  4324231.19    377661.06
# 2018  WestTexNewMexico  13384586.80  5719096.61    309467.53

# %% [markdown]
# A partir del dataframe `group_bags` muestra en qué año y en qué región se vendió el máximo número de bolsas pequeñas de aguacates.

# %%
# your code here
group_bags[group_bags["Small Bags"]==group_bags["Small Bags"].max()].region.to_frame()
# Out:
#                 region
# Date
# 2018  WestTexNewMexico

# %% [markdown]
# Asigna a la variable `avocado_months` el dataframe `avocado` agrupado por **meses** y por la media de los valores de cada columna. Hay dos maneras diferentes de resolver este ejercicio, sin embargo, con uno sería suficiente.
#
# Muestra solo los primeros 15 valores.

# %%
#your code here
avocado_months = avocado.groupby(avocado.index.to_period('M')).mean()
avocado_months.head(15)
# Out:
#          AveragePrice   Total Volume           4046           4225  \
# Date
# 2015-01      1.365046  736308.355532  296829.313565  301506.093912
# 2015-02      1.326944  839438.887106  354552.080000  334110.463727
# 2015-03      1.361981  775153.832907  324630.507778  299831.998981
# 2015-04      1.383449  796630.544329  348567.729491  291150.142593
# 2015-05      1.344685  895896.379241  394883.681407  330662.679722
# 2015-06      1.399074  883858.203032  374715.185903  317095.642338
# 2015-07      1.409444  825698.779236  326456.573750  321060.962685
# 2015-08      1.444481  776379.286704  300310.837796  321335.405667
# 2015-09      1.449144  762080.632060  247781.252500  356497.374190
# 2015-10      1.391968  707815.071806  214976.447894  331744.578704
# 2015-11      1.330611  684148.215537  230572.546722  292348.258463
# 2015-12      1.305244  686835.108794  230718.662738  268747.887401
# 2016-01      1.240185  880381.047370  248846.960093  354846.291574
# 2016-02      1.237106  992235.652731  303715.019931  372600.768704
# 2016-03      1.224213  905584.278426  276501.768171  330062.790810
#
#                  4770     Total Bags     Small Bags    Large Bags  \
# Date
# 2015-01  20635.684028  117337.264028   96502.584213  20513.634144
# 2015-02  24220.692431  126555.650949  106004.821690  20017.510602
# 2015-03  23068.926037  127622.400111  109589.476796  17325.542056
# 2015-04  22056.120440  134856.551806  114351.516134  19976.716250
# 2015-05  23923.426833  146426.591278  123510.636407  22365.188204
# 2015-06  28241.728264  163805.646528  140095.819745  22889.726667
# 2015-07  27713.835718  150467.386250  126518.964097  23135.342292
# 2015-08  25399.461870  129333.573963  109437.493519  18895.924852
# 2015-09  27756.865671  130045.139699  100038.074236  28664.317685
# 2015-10  32360.636991  128733.408218   99441.142894  28159.288125
# 2015-11  24339.130463  136888.279889  106598.555463  29190.574759
# 2015-12  26654.108329  160714.450325  125089.361833  32706.897680
# 2016-01  36216.326611  240471.469093  176353.023167  61009.767944
# 2016-02  44169.501713  271750.362384  199309.627477  69751.625301
# 2016-03  42992.560046  256027.159398  193483.747222  60488.572407
#
#          XLarge Bags  year
# Date
# 2015-01   321.045671  2015
# 2015-02   533.318657  2015
# 2015-03   707.381259  2015
# 2015-04   528.319421  2015
# 2015-05   550.766667  2015
# 2015-06   820.100116  2015
# 2015-07   813.075231  2015
# 2015-08  1000.153741  2015
# 2015-09  1342.747778  2015
# 2015-10  1132.977199  2015
# 2015-11  1099.149667  2015
# 2015-12  2918.190812  2015
# 2016-01  3108.677981  2016
# 2016-02  2689.109606  2016
# 2016-03  2054.839769  2016

# %% [markdown]
# A partir de avocado_months calcula el precio máximo de los aguacates de los meses de enero.

# %%
# your code here
avocado_months["month"] = avocado_months.index.month

# %%
avocado_months.groupby("month")["AveragePrice"].max().head(1)
# Out:
# month
# 1    1.387431
# Name: AveragePrice, dtype: float64

# %% [markdown]
# Asigna a la variable `avocado_tri` el dataframe `avocado` agrupado por **trimestre** y el sumatorio de los valores de cada columna.

# %%
# your code here
avocado_tri = avocado_months.resample('Q').agg(['sum'])

# %%
avocado_tri.head()
# Out:
#        AveragePrice  Total Volume          4046          4225           4770  \
#                 sum           sum           sum           sum            sum
# Date
# 2015Q1     4.053972  2.350901e+06  9.760119e+05  9.354486e+05   67925.302495
# 2015Q2     4.127208  2.576385e+06  1.118167e+06  9.389085e+05   74221.275537
# 2015Q3     4.303069  2.364159e+06  8.745487e+05  9.988937e+05   80870.163259
# 2015Q4     4.027822  2.078798e+06  6.762677e+05  8.928407e+05   83353.875783
# 2016Q1     3.701505  2.778201e+06  8.290637e+05  1.057510e+06  123378.388370
#
#            Total Bags     Small Bags     Large Bags  XLarge Bags  year month
#                   sum            sum            sum          sum   sum   sum
# Date
# 2015Q1  371515.315088  312096.882699   57856.686801  1561.745588  6045     6
# 2015Q2  445088.789611  377957.972287   65231.631120  1899.186204  6045    15
# 2015Q3  409846.099912  335994.531852   70695.584829  3155.976750  6045    24
# 2015Q4  426336.138431  331129.060189   90056.760564  5150.317678  6045    33
# 2016Q1  768248.990875  569146.397866  191249.965653  7852.627356  6048     6

# %% [markdown]
# Crea un subset de `avocado` en el que solo se incluyan las siguientes columnas: `"AveragePrice"`,`"Total Volume"`,`"type"`,`"year"` y `"region"`, llámalo `avo_subset`.

# %%
# your code here
avo_subset = avocado.loc[:,["AveragePrice","Total Volume","type","year","region"]]

# %%
avo_subset
# Out:
#             AveragePrice  Total Volume          type  year              region
# Date
# 2015-01-04          1.75      27365.89       organic  2015           Southeast
# 2015-01-04          1.49      17723.17       organic  2015             Chicago
# 2015-01-04          1.68       2896.72       organic  2015  HarrisburgScranton
# 2015-01-04          1.52      54956.80  conventional  2015          Pittsburgh
# 2015-01-04          1.64       1505.12       organic  2015               Boise
# ...                  ...           ...           ...   ...                 ...
# 2018-03-25          1.36     908202.13  conventional  2018             Chicago
# 2018-03-25          0.70    9010588.32  conventional  2018        SouthCentral
# 2018-03-25          1.42     163496.70       organic  2018        SouthCentral
# 2018-03-25          1.70     190257.38       organic  2018          California
# 2018-03-25          1.34    1774776.77  conventional  2018             NewYork
#
# [18249 rows x 5 columns]

# %%
avo_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 18249 entries, 2015-01-04 to 2018-03-25
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   type          18249 non-null  object
#  3   year          18249 non-null  int64
#  4   region        18249 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# Filtra el dataframe `avo_subset` de modo que muestre solo aquellos datos de los aguacates tipo organic en la region de California durante el año 2017. Llama a la variable `org_Cal`.

# %%
# your code here
org_Cal = avo_subset[(avo_subset.type=="organic") & (avo_subset.region=="California") & (avo_subset.year==2017)]

# %%
org_Cal.head()
# Out:
#             AveragePrice  Total Volume     type  year      region
# Date
# 2017-01-01          1.46     164137.04  organic  2017  California
# 2017-01-08          1.50     177777.40  organic  2017  California
# 2017-01-15          1.66     142739.21  organic  2017  California
# 2017-01-22          1.53     136422.97  organic  2017  California
# 2017-01-29          1.44     165225.54  organic  2017  California

# %%
org_Cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53 entries, 2017-01-01 to 2017-12-31
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  53 non-null     float64
#  1   Total Volume  53 non-null     float64
#  2   type          53 non-null     object
#  3   year          53 non-null     int64
#  4   region        53 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
org_Cal.shape
# Out:
# (53, 5)

# %% [markdown]
# Usando `org_Cal` saca la mediana del volumen total.

# %%
# your code here
org_Cal["Total Volume"].median()
# Out:
# 152064.59

# %% [markdown]
# ¿Qué precio medio había el día que el volumen total fue igual a la mediana de la mencionada columna, `"Total Volume"`?

# %%
# your code here
org_Cal[org_Cal["Total Volume"]==org_Cal["Total Volume"].median()]#["AveragePrice"]
# Out:
#             AveragePrice  Total Volume     type  year      region
# Date
# 2017-09-17          2.18     152064.59  organic  2017  California

# %% [markdown]
# Muestra la evolución del precio medio, `"AveragePrice"`, de los aguacates de tipo orgánicos de California durante el año 2017 con un gráfico de una línea, usando `org_Cal`.

# %%
# your code here
fig = plt.gcf()
org_Cal["AveragePrice"].plot(title = "California Organic Avocadoes  - 2017, Average Price", grid = True, figsize=(13,9))

# %% [markdown]
# A partir del subset `avo_subset` trata de sacar un gráfico en el que se pueda observar la cantidad de aguacates de tipo **conventional**, a lo largo de todos los periodos.
#
# Haz un gráfico simple usando la librería **pandas**.

# %%
# your code here
avo_subset.head()
# Out:
#             AveragePrice  Total Volume          type  year              region
# Date
# 2015-01-04          1.75      27365.89       organic  2015           Southeast
# 2015-01-04          1.49      17723.17       organic  2015             Chicago
# 2015-01-04          1.68       2896.72       organic  2015  HarrisburgScranton
# 2015-01-04          1.52      54956.80  conventional  2015          Pittsburgh
# 2015-01-04          1.64       1505.12       organic  2015               Boise

# %%
avo_subset_conv= avo_subset[avo_subset.type == "conventional"]
avo_subset_conv["Total Volume"].plot()

# %% [markdown]
# Crea una función **lambda** que quite los dos primeros dígitos de cada año de la columna `"year"` y lo convierta a string.
# Después aplica esta función a toda la columna del dataframe `avo_subset`.
#
# Ejemplo: `2015` --> `"15"`

# %%
# your code here
avo_subset.year = avo_subset.year.astype(str)
extract = lambda x: x[2:]
avo_subset["year"] = avo_subset['year'].apply(extract)

# %%
avo_subset
# Out:
#             AveragePrice  Total Volume          type year              region
# Date
# 2015-01-04          1.75      27365.89       organic   15           Southeast
# 2015-01-04          1.49      17723.17       organic   15             Chicago
# 2015-01-04          1.68       2896.72       organic   15  HarrisburgScranton
# 2015-01-04          1.52      54956.80  conventional   15          Pittsburgh
# 2015-01-04          1.64       1505.12       organic   15               Boise
# ...                  ...           ...           ...  ...                 ...
# 2018-03-25          1.36     908202.13  conventional   18             Chicago
# 2018-03-25          0.70    9010588.32  conventional   18        SouthCentral
# 2018-03-25          1.42     163496.70       organic   18        SouthCentral
# 2018-03-25          1.70     190257.38       organic   18          California
# 2018-03-25          1.34    1774776.77  conventional   18             NewYork
#
# [18249 rows x 5 columns]

# %% [markdown]
# # ¡Ya tienes un 10!

# %% [markdown]
# **No te conformes y si te sobra tiempo, ve a por el 11 o si no, recupera algún puntito si algún ejercicio se te ha quedado atascado. ¡Otra oportunidad!**

# %% [markdown]
# En esta misma carpeta encontrarás un archivo llamado `supermarket_region.csv`, asígnalo a la variable `supermarket` y muestra los primeros 5 filas.

# %%
# your code here
supermarket = pd.read_csv("supermarket_region.csv")
supermarket.head()
# Out:
#                 region                                            Address  \
# 0             Midsouth                                                  0
# 1        DallasFtWorth  2025 Fort Worth Ave, Dallas, TX 75208, Estados...
# 2              Detroit    575 Brush St, Detroit, MI 48226, Estados Unidos
# 3  HartfordSpringfield  1106 Union St, West Springfield, MA 01089, Est...
# 4                Tampa  8401 N Armenia Ave, Tampa, FL 33604, Estados U...
#
#                  Supermarket Name
# 0                               0
# 1   Elrod's Cost Plus Supermarket
# 2                     City Market
# 3  Price Rite of West Springfield
# 4              Quadro Supermarket

# %% [markdown]
# El dataframe `supermarket` y `avo_subset` tienen una columna en común que es `region`, sabiendo esto, utiliza el método adecuado para unir ambos dataframes en uno llamado `avo_merged`.
#
# Si lo has hecho bien, no debería salir ningún **null**.

# %%
avo_subset.head()
# Out:
#             AveragePrice  Total Volume          type year              region
# Date
# 2015-01-04          1.75      27365.89       organic   15           Southeast
# 2015-01-04          1.49      17723.17       organic   15             Chicago
# 2015-01-04          1.68       2896.72       organic   15  HarrisburgScranton
# 2015-01-04          1.52      54956.80  conventional   15          Pittsburgh
# 2015-01-04          1.64       1505.12       organic   15               Boise

# %%
# your code here
avo_merged = pd.merge(supermarket, avo_subset, on='region', how='inner')

# %%
avo_merged.isnull().sum()
# Out:
# region              0
# Address             0
# Supermarket Name    0
# AveragePrice        0
# Total Volume        0
# type                0
# year                0
# dtype: int64

# %% [markdown]
# Guarda `avo_merged` como un `.json` usando la función de **pandas** correspondiente, el nombre del archivo deberá ser `"avo_merged.json"`.

# %%
# your code here
avo_merged.to_json("avo_merged.json")
