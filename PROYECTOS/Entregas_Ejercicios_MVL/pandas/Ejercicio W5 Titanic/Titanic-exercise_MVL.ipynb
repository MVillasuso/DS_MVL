# %% [markdown]
#    #                                                  Titanic Exercise
#    #### Practise Pandas

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns
# you will have to import at least two other libraries along the exercise

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
filename = "titanic.csv"

# %%
titanic = pd.read_csv(filename)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# Describe de las columnas numéricas solamente
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
#Describe de TODAS las columnas
titanic.describe(include = "all")
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881138
# std        0.837836     0.486055                   NaN   NaN    14.413493
# min        1.000000     0.000000                   NaN   NaN     0.170000
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
#Primeras 5 filas del DF
titanic.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Muestra cada columna y su tipo
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
#your code

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 107.4+ KB

# %%
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Out:
# (1309, 14)

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
# Selección utilizando LOC
people = titanic.loc[:, ["name", "sex","age"]]
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
# Creación del DF utilizando posición del índice ILOC
people = titanic.iloc[:,2:5]

# %%
people.head()
# Out:
#                                               name     sex    age
# 0                    Allen, Miss. Elisabeth Walton  female  29.00
# 1                   Allison, Master. Hudson Trevor    male   0.92
# 2                     Allison, Miss. Helen Loraine  female   2.00
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00

# %%
#your code

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
#Uso de append, head y tail en la misma instrucción
people.head(3).append(people.tail(4))
# Out:
#                                 name     sex    age
# 0      Allen, Miss. Elisabeth Walton  female  29.00
# 1     Allison, Master. Hudson Trevor    male   0.92
# 2       Allison, Miss. Helen Loraine  female   2.00
# 1305           Zabour, Miss. Thamine  female    NaN
# 1306       Zakarian, Mr. Mapriededer    male  26.50
# 1307             Zakarian, Mr. Ortin    male  27.00
# 1308              Zimmerman, Mr. Leo    male  29.00

# %%
titanic.head(3).append(titanic.tail(4))
# Out:
#       pclass  survived                            name     sex    age  sibsp  \
# 0          1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1          1         1  Allison, Master. Hudson Trevor    male   0.92      1
# 2          1         0    Allison, Miss. Helen Loraine  female   2.00      1
# 1305       3         0           Zabour, Miss. Thamine  female    NaN      1
# 1306       3         0       Zakarian, Mr. Mapriededer    male  26.50      0
# 1307       3         0             Zakarian, Mr. Ortin    male  27.00      0
# 1308       3         0              Zimmerman, Mr. Leo    male  29.00      0
#
#       parch  ticket      fare    cabin embarked boat   body  \
# 0         0   24160  211.3375       B5        S    2    NaN
# 1         2  113781  151.5500  C22 C26        S   11    NaN
# 2         2  113781  151.5500  C22 C26        S  NaN    NaN
# 1305      0    2665   14.4542      NaN        C  NaN    NaN
# ...

# %%
#your code

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
# Seleccionar un grupo de filas del DF titanic
s_titanic = titanic.iloc[3:10,:]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %%
#your code

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
# Seleccionar las filas por posición del índice y ordenarlas según el índice en orden reverso
s_titanic_rev = titanic.iloc[40:64,:].sort_index(ascending= False)
s_titanic_rev
# Out:
#     pclass  survived                                               name  \
# 63       1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# ...

# %%
#your code

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.loc[:,:"parch"]
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %%
#your code

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:,"name":"age"]
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
#your code

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.loc[:,"ticket":]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %%
#your code

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %%
deads = titanic[titanic.survived==0]                    #DF con No sobrevivientes
oldest_dead = deads[(deads.age == deads.age.max())]     #DF con el mayor de los NO sobrevivientes
oldest_dead
# Out:
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1235       3         0  Svensson, Mr. Johan  male  74.0      0      0  347060
#
#        fare cabin embarked boat  body home.dest
# 1235  7.775   NaN        S  NaN   NaN       NaN

# %%
#your code

# %%
resp= oldest_dead.iloc[0, 2:7].to_frame()
resp
# Out:
#                       1235
# name   Svensson, Mr. Johan
# sex                   male
# age                     74
# sibsp                    0
# parch                    0

# %%
nombre = oldest_dead.iloc [0,2]
companions = (oldest_dead.iloc[0,5]+ oldest_dead.iloc[0,6])
edad = oldest_dead.iloc [0,4]
sexo = oldest_dead.iloc [0,3]

if companions == 0:
    comp = ", and it was travelling alone"
else:
    comp = ", and it was travelling with " + str(companions) + " companions"

print("The oldest died person was ", nombre, ", ",  edad , " years old, " , sexo , comp)
# Out:
# The oldest died person was  Svensson, Mr. Johan ,  74.0  years old,  male , and it was travelling alone

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %%
#your code

# %%
rows = np.random.randint(0,(titanic.shape[0]+1), 5).tolist()
rows
# Out:
# [1185, 742, 20, 252, 770]

# %% [markdown]
# This list of numbers are random, could be different.

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
#your code

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic.columns.values[3]
# Out:
# 'sex'

# %%
titanic.columns.tolist()
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
# Creación de una lista aleatoria de columnas

colindx = np.random.randint(0,titanic.shape[1],3).tolist()    #Escojo 3 nros aleatorios
cols = [titanic.columns.values[elem] for elem in colindx]     # Creo una lista con los valores de esas columnas

cols
# Out:
# ['ticket', 'fare', 'sex']

# %%
# o tambien 
listacols = titanic.columns.tolist()            # Lista de las columnas de titanic
cols = [random.choice(listacols) for n in range(3)]     # Lista con 3 columnas seleccionadas aleatoriamenteur
cols
# Out:
# ['sex', 'survived', 'sex']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
#your code

# %%
print(rows)
print(cols)
newdf = titanic.loc[rows,cols]
newdf
# Out:
# [1185, 742, 20, 252, 770]
# ['sex', 'survived', 'sex']
#        sex  survived   sex
# 1185  male         0  male
# 742   male         1  male
# 20    male         1  male
# 252   male         0  male
# 770   male         0  male

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %% [markdown]
# Bonus: Rename the column `"sex"` to `"gender"`

# %%
a = np.array(titanic.sex)
a
# Out:
# array(['female', 'male', 'female', ..., 'male', 'male', 'male'],
#       dtype=object)

# %%
array_fe = a == "female"
array_fe
# Out:
# array([ True, False,  True, ..., False, False, False])

# %%
array_fe.dtype
# Out:
# dtype('bool')

# %%
np.count_nonzero(array_fe==False)
# Out:
# 843

# %%
np.count_nonzero(array_fe == True)
# Out:
# 466

# %%
#your code

# %%
titanic.rename(columns={"sex":"gender"}, inplace = True)

# %%
titanic.head(5)
# Out:
#    pclass  survived                                             name  gender  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# 14. Filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
#your code

# %%
array_fe
# Out:
# array([ True, False,  True, ..., False, False, False])

# %%
woman_titanic = titanic[array_fe]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
#your code
#Este valor esta incorrecto pues corresponde a las mayores a 18

# %%
woman_titanic[woman_titanic.age<18]["name"].count()
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
#your code
#Este valor esta incorrecto pues corresponde a las mayores a 18

# %%
dead_wo= woman_titanic[(woman_titanic.age <18) & (woman_titanic.survived==0) ]["name"].count()
dead_wo
# Out:
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
#your code

# %%
titanic.dropna(how='any').shape
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
#your code

# %%
titanic.dropna(how='all').shape
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
#your code

# %%
titanic.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# Lista de columnas con más de 1000 valores nulos
lelim = titanic.columns[titanic.isna().sum() >1000].tolist()
lelim
# Out:
# ['cabin', 'body']

# %%
#Eliminación de las columnas de la  lista anterior
titanic.drop(columns=lelim, axis=1).columns
# Out:
# Index(['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'embarked', 'boat', 'home.dest'],
#       dtype='object')

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
#your code

# %%
boat_missing = round((titanic.boat.isnull().sum() / titanic.boat.size) * 100,2)
print( boat_missing.astype(str) +" % " + "of the data in the column 'boat' are null")
# Out:
# 62.87 % of the data in the column 'boat' are null

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` --> `by_class`

# %%
#your code

# %%
titanic.groupby("pclass").agg({"age" : ["max", "median"], "fare" : ["max", "median"]}, axis =1)
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
#your code

# %%
titanic.groupby("pclass")["age"].max()
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: age, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
#your code

# %%
titanic.groupby("pclass")["fare"].median()
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: fare, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
#your code

# %%
counted = pd.pivot_table(data=titanic[(titanic.survived == 1)], values="name", index="pclass", columns="gender", aggfunc="count")
counted
# Out:
# gender  female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %%
counted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 1 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   female  3 non-null      int64
#  1   male    3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0 bytes

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
#your code

# %%
counted["total"] = counted["female"] + counted["male"]
counted
# Out:
# gender  female  male  total
# pclass
# 1          139    61    200
# 2           94    25    119
# 3          106    75    181

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the more?

# %%
#your code

# %%
counted.sort_values(by = "total", ascending = False).head(1)
# Out:
# gender  female  male  total
# pclass
# 1          139    61    200

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
#your code

# %%
titanic[(titanic.gender=="female") & (titanic.pclass == 3) & (titanic.age < 30) & (titanic.survived == True)]
# Out:
#       pclass  survived                                               name  \
# 604        3         1                        Abelseth, Miss. Karen Marie
# 607        3         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 612        3         1                         Aks, Mrs. Sam (Leah Rosen)
# 621        3         1    Andersen-Jensen, Miss. Carla Christine Nielsine
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 643        3         1                     Asplund, Miss. Lillian Gertrud
# 653        3         1                               Ayoub, Miss. Banoura
# 657        3         1                             Baclini, Miss. Eugenie
# 658        3         1                      Baclini, Miss. Helene Barbara
# 659        3         1                     Baclini, Miss. Marie Catherine
# 660        3         1              Baclini, Mrs. Solomon (Latifa Qurban)
# 661        3         1                         Badman, Miss. Emily Louisa
# ...

# %%
len(titanic[(titanic.gender=="female") & (titanic.pclass == 3) & (titanic.age < 30) & (titanic.survived == True)])
# Out:
# 57

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
#your code

# %%
cond = (titanic.gender == "male") & (titanic.pclass == 1) & (titanic.age > 50) & (titanic.survived==False)

# %%
len(titanic[cond])
# Out:
# 29

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
#your code

# %%
titanic.name.unique()
# Out:
# array(['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor',
#        'Allison, Miss. Helen Loraine', ..., 'Zakarian, Mr. Mapriededer',
#        'Zakarian, Mr. Ortin', 'Zimmerman, Mr. Leo'], dtype=object)

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
#your code

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
totalbyname= titanic.name.value_counts(ascending=False)

# %%
totalbyname[totalbyname.values >1].index.tolist()
# Out:
# ['Connolly, Miss. Kate', 'Kelly, Mr. James']

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
#your code

# %%
titanic.hist("age")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff4efc438e0>]],
#       dtype=object)

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
#your code

# %%
serbysex = titanic["gender"].value_counts()
serbysex.plot(kind='bar')
plt.show()

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
#your code

# %%
sns.countplot(x="gender" , data=titanic)

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](catplotgen.png)

# %%
sns.catplot(x="gender", y="survived", kind="bar", data=titanic);

# %%
"Women are more likely to survive shipwrecks"
# Out:
# 'Women are more likely to survive shipwrecks'

# %%
#your code

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](kdeplotsur.png)

# %%
tit_deads = titanic[titanic.survived == 0]
tit_deads.shape
# Out:
# (809, 14)

# %%
tit_deads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 809 entries, 2 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     809 non-null    int64
#  1   survived   809 non-null    int64
#  2   name       809 non-null    object
#  3   gender     809 non-null    object
#  4   age        619 non-null    float64
#  5   sibsp      809 non-null    int64
#  6   parch      809 non-null    int64
#  7   ticket     809 non-null    object
#  8   fare       808 non-null    float64
#  9   cabin      102 non-null    object
#  10  embarked   809 non-null    object
#  11  boat       9 non-null      object
#  12  body       121 non-null    float64
#  13  home.dest  398 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 94.8+ KB

# %%
tit_deads.drop(columns= ["survived", "name", "sibsp", "parch", "ticket", "fare", "cabin", "embarked", "boat", "body", "home.dest"], inplace=True)

# %%
tit_deads.head(5)
# Out:
#    pclass  gender   age
# 2       1  female   2.0
# 3       1    male  30.0
# 4       1  female  25.0
# 7       1    male  39.0
# 9       1    male  71.0

# %%
display(tit_deads)
# Out:
#       pclass  gender   age
# 2          1  female   2.0
# 3          1    male  30.0
# 4          1  female  25.0
# 7          1    male  39.0
# 9          1    male  71.0
# ...      ...     ...   ...
# 1304       3  female  14.5
# 1305       3  female   NaN
# 1306       3    male  26.5
# 1307       3    male  27.0
# 1308       3    male  29.0
#
# [809 rows x 3 columns]

# %%
tit_deads[tit_deads.age.isna()].count()
# Out:
# pclass    190
# gender    190
# age         0
# dtype: int64

# %%
#Reemplace todas las edades null por cero
# tit_deads.fillna(0,inplace=True)

# %%
# o borrando las filas donde las edades sean cero
tit_deads.dropna(axis=0, how='any', inplace = True)

# %%
tit_deads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 619 entries, 2 to 1308
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pclass  619 non-null    int64
#  1   gender  619 non-null    object
#  2   age     619 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 19.3+ KB

# %%
#your code
sns.set(style="whitegrid")
sns.kdeplot(data= tit_deads.age,color = "red", label = "Not Survived",shade = True)

# %%
#Por edad y clase (Los fallecidos de primera clase eran mayores)
fg = sns.FacetGrid(tit_deads, hue="pclass", aspect=3)
fg.map(sns.kdeplot, "age", shade=True)

# %%
# breakdown by age and sex
fg = sns.FacetGrid(titanic, col="gender", row="pclass", hue="gender", size=2.5, aspect=2.5)
fg.map(sns.kdeplot, "age", shade=True)

# %%
#Por edad y género
fg = sns.FacetGrid(tit_deads, hue="gender", aspect=3)
fg.map(sns.kdeplot, "age", shade=True)
