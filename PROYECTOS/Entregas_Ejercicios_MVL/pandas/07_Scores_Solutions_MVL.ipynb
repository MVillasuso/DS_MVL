# %% [markdown]
# # Scores

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 

# %matplotlib inline

# %% [markdown]
# ### Step 2. Create the DataFrame it should look like below.

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],  
        'age': [42,52,36,24,73],
        'female': [0,1,1,0,1],
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}

# %%
reg = pd.DataFrame(raw_data)

# %%
reg
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
reg.plot.scatter (x='preTestScore',
                    y='postTestScore',
                    title = ('Scatter plot of preTestScore and postTestScore by age'),
                    c ='red',           # Color de los puntos
                    s = reg.age)        #Varía el tamano del punto en base a la edad
plt.show(block=True)

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
sex_val =lambda x: 'F' if x else 'M'
reg['sex'] = reg['female'].apply(sex_val)

# %%
reg
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore sex
# 0      Jason    Miller   42       0             4             25   M
# 1      Molly  Jacobson   52       1            24             94   F
# 2       Tina       Ali   36       1            31             57   F
# 3       Jake    Milner   24       0             2             62   M
# 4        Amy     Cooze   73       1             3             70   F

# %%
# USANDO  MATPLOT
colorv = reg['sex'].map({'M': 'b', 'F': 'r'})

reg.plot.scatter (  x='preTestScore',
                    y='postTestScore',
                    title = ('Scatter plot of preTestScore and postTestScore by age'),
                    c = colorv,                        # Color de los puntos segun el sexo
                    alpha = 0.3,                        # Para la transparencia de los puntos
                    s = reg.postTestScore * 4.5)        #Varía el tamano del punto en base a postTestScore
plt.show(block=True)

# %%
#USANDO SEABORN
sns.set_style(style="darkgrid")

sns.FacetGrid(reg, margin_titles=False, height=5, legend_out=True, xlim =(0,50), ylim=(0,100))
ax = sns.scatterplot(x="preTestScore", y="postTestScore", hue="sex",
             alpha=.5, palette="bright", size = (reg.postTestScore * 4.5), 
            data=reg)
ax.set_title("Scatter plot of preTestScore and postTestScore by sex")

plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1, borderaxespad=-3.5)

plt.show()
